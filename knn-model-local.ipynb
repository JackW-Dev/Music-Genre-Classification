# %% [markdown]
# # K-Nearest Neighbour Model -- LOCAL
# This version is a basic test and currently works locally.
# The model will be stored for use in an Azure workspace.

# %% [markdown]
# ## Importing libraries

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import pandas as pd
import matplotlib.pyplot as plt

#ADD MARKDOWN CELLS TO DESCRIBE THE FOLLOWING

#Taken from https://medium.com/@plog397/auc-roc-curve-scoring-function-for-multi-class-classification-9822871a6659
#By default, the sklearn implementation does not support multiclass input.
#The function below converts into a binary input.
def multiclass_auc_roc(y_test, y_pred):
    label = LabelBinarizer()
    label.fit(y_test)
    y_test = label.transform(y_test)
    y_pred = label.transform(y_pred)
    return metrics.roc_auc_score(y_test, y_pred)

music_df = pd.read_csv(r'D:\Uni\Y3\FYP\Code\Music Classification\extracted-features.csv')

#Read in CSV as a Pandas DataFrame
# print(music_df)
#Drop the TrackNum from the DataFrame (This is not important for classification)
music_df.drop('TrackNum', 1, inplace = True)
#Check the field has been dropped correctly
# print(music_df)

#   This will contain the data
data = music_df.iloc[:, 1:5].values
#   This will contain the labels corresponding to the data
labels = music_df.iloc[:, 0].values

data_train, data_test, labels_train, labels_test = train_test_split(data, labels, test_size = 0.2)

# print(x_train.shape)
# print(x_test.shape)
# print(y_train.shape)
# print(y_test.shape)

k_range = range(1, 25)
accuracy_scores_list = []
auroc_scores_list = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(data_train, labels_train)
    y_pred = knn.predict(data_test)

    accuracy_scores_list.append(metrics.accuracy_score(labels_test, y_pred))
    auroc_scores_list.append(multiclass_auc_roc(labels_test, y_pred))

plt.plot(k_range, accuracy_scores_list)
plt.plot(k_range, auroc_scores_list)
plt.xlabel("K Value")
plt.ylabel("Testing Accuracy")
plt.show()

for i in range(0, len(accuracy_scores_list)):
    print("K value: " + str(i + 1) + " Testing Accuracy: " + str(accuracy_scores_list[i]))
    print("K value: " + str(i + 1) + " AUROC Accuracy: " + str(auroc_scores_list[i]))
# Out:
# K value: 1 Testing Accuracy: 0.31
# K value: 1 AUROC Accuracy: 0.6145257699195674
# K value: 2 Testing Accuracy: 0.225
# K value: 2 AUROC Accuracy: 0.5786347414908655
# K value: 3 Testing Accuracy: 0.235
# K value: 3 AUROC Accuracy: 0.5823897710835861
# K value: 4 Testing Accuracy: 0.205
# K value: 4 AUROC Accuracy: 0.5586672438251301
# K value: 5 Testing Accuracy: 0.23
# K value: 5 AUROC Accuracy: 0.5748665031215657
# K value: 6 Testing Accuracy: 0.235
# K value: 6 AUROC Accuracy: 0.5765643034328689
# K value: 7 Testing Accuracy: 0.225
# K value: 7 AUROC Accuracy: 0.5700087246978311
# K value: 8 Testing Accuracy: 0.225
# K value: 8 AUROC Accuracy: 0.5697856795042932
# K value: 9 Testing Accuracy: 0.24
# K value: 9 AUROC Accuracy: 0.5788984075019702
# K value: 10 Testing Accuracy: 0.25
# K value: 10 AUROC Accuracy: 0.5862080085604553
# K value: 11 Testing Accuracy: 0.22
# K value: 11 AUROC Accuracy: 0.5662462366850285
# K value: 12 Testing Accuracy: 0.22
# K value: 12 AUROC Accuracy: 0.564208597566827
# K value: 13 Testing Accuracy: 0.205
# K value: 13 AUROC Accuracy: 0.5570089905442169
# K value: 14 Testing Accuracy: 0.21
# K value: 14 AUROC Accuracy: 0.5627474408141988
# K value: 15 Testing Accuracy: 0.22
# K value: 15 AUROC Accuracy: 0.5664563215326595
# K value: 16 Testing Accuracy: 0.225
# K value: 16 AUROC Accuracy: 0.5672990188634947
# K value: 17 Testing Accuracy: 0.22
# K value: 17 AUROC Accuracy: 0.5661636784398192
# K value: 18 Testing Accuracy: 0.21
# K value: 18 AUROC Accuracy: 0.5600272739976646
# K value: 19 Testing Accuracy: 0.215
# K value: 19 AUROC Accuracy: 0.5639228876183032
# K value: 20 Testing Accuracy: 0.215
# K value: 20 AUROC Accuracy: 0.5652813532152666
# K value: 21 Testing Accuracy: 0.215
# K value: 21 AUROC Accuracy: 0.5659853605308415
# K value: 22 Testing Accuracy: 0.205
# K value: 22 AUROC Accuracy: 0.5589894411089957
# K value: 23 Testing Accuracy: 0.215
# K value: 23 AUROC Accuracy: 0.563802956573233
# K value: 24 Testing Accuracy: 0.22
# K value: 24 AUROC Accuracy: 0.5657580643815117
# K value: 25 Testing Accuracy: 0.205
# K value: 25 AUROC Accuracy: 0.5578281378183457
# K value: 26 Testing Accuracy: 0.19
# K value: 26 AUROC Accuracy: 0.5495865153076653
# K value: 27 Testing Accuracy: 0.21
# K value: 27 AUROC Accuracy: 0.560839287058547
# K value: 28 Testing Accuracy: 0.215
# K value: 28 AUROC Accuracy: 0.5630815434359329
# K value: 29 Testing Accuracy: 0.225
# K value: 29 AUROC Accuracy: 0.5706913704220333
# K value: 30 Testing Accuracy: 0.23
# K value: 30 AUROC Accuracy: 0.5714814390339709
# K value: 31 Testing Accuracy: 0.235
# K value: 31 AUROC Accuracy: 0.5764293127878917
# K value: 32 Testing Accuracy: 0.225
# K value: 32 AUROC Accuracy: 0.5699971463795841
# K value: 33 Testing Accuracy: 0.225
# K value: 33 AUROC Accuracy: 0.5710713423362
# K value: 34 Testing Accuracy: 0.23
# K value: 34 AUROC Accuracy: 0.5718303145873651
# K value: 35 Testing Accuracy: 0.235
# K value: 35 AUROC Accuracy: 0.5770800724608497
# K value: 36 Testing Accuracy: 0.22
# K value: 36 AUROC Accuracy: 0.5669825689061853
# K value: 37 Testing Accuracy: 0.23
# K value: 37 AUROC Accuracy: 0.5728623756545255
# K value: 38 Testing Accuracy: 0.235
# K value: 38 AUROC Accuracy: 0.5783182104145171
# K value: 39 Testing Accuracy: 0.22
# K value: 39 AUROC Accuracy: 0.56826157775961
# K value: 40 Testing Accuracy: 0.215
# K value: 40 AUROC Accuracy: 0.5659634635553512
# K value: 41 Testing Accuracy: 0.195
# K value: 41 AUROC Accuracy: 0.5542159476961553
# K value: 42 Testing Accuracy: 0.205
# K value: 42 AUROC Accuracy: 0.5589866555165159
# K value: 43 Testing Accuracy: 0.19
# K value: 43 AUROC Accuracy: 0.550811514180384
# K value: 44 Testing Accuracy: 0.185
# K value: 44 AUROC Accuracy: 0.5494001047648525
# K value: 45 Testing Accuracy: 0.18
# K value: 45 AUROC Accuracy: 0.5471223438517323
# K value: 46 Testing Accuracy: 0.19
# K value: 46 AUROC Accuracy: 0.5520615590314977
# K value: 47 Testing Accuracy: 0.2
# K value: 47 AUROC Accuracy: 0.5582188176301626
# K value: 48 Testing Accuracy: 0.195
# K value: 48 AUROC Accuracy: 0.5562603145243709
# K value: 49 Testing Accuracy: 0.19
# K value: 49 AUROC Accuracy: 0.554301498018593
